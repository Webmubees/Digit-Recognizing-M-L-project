# %% [markdown]
# <a href="https://colab.research.google.com/github/Webmubees/Digit-Recognizing-M-L-project/blob/main/digitrecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from PIL import Image

# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype("float32") / 255.0

# Define the CNN model architecture
model = keras.Sequential([
    layers.Input(shape=(28, 28, 1)),
    layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dropout(0.5),
    layers.Dense(10, activation="softmax")
])

# Compile the model
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
model.fit(x_train, y_train, batch_size=128, epochs=5, validation_split=0.1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test accuracy:", test_accuracy)

# Function to preprocess user-provided images
def preprocess_image(image_path):
    img = Image.open(image_path).convert('L')  # Convert to grayscale
    img = img.resize((28, 28))  # Resize to 28x28
    img_array = np.array(img)
    img_array = img_array.reshape(1, 28, 28, 1).astype('float32') / 255.0  # Reshape and normalize
    return img_array

# Function to predict on user-provided images
def predict_image(model, image_path):
    preprocessed_image = preprocess_image(image_path)
    prediction = model.predict(preprocessed_image)
    predicted_class = np.argmax(prediction)
    return predicted_class

# Example usage
image_path = "C:\\Users\\hp\\Downloads\\digit.jpg"
predicted_digit = predict_image(model, image_path)
print("Predicted digit:", predicted_digit)
# Out:
# Epoch 1/5
# 422/422 [==============================] - 41s 96ms/step - loss: 0.3724 - accuracy: 0.8854 - val_loss: 0.0834 - val_accuracy: 0.9785
# Epoch 2/5
# 422/422 [==============================] - 39s 92ms/step - loss: 0.1171 - accuracy: 0.9647 - val_loss: 0.0560 - val_accuracy: 0.9845
# Epoch 3/5
# 422/422 [==============================] - 38s 91ms/step - loss: 0.0857 - accuracy: 0.9736 - val_loss: 0.0470 - val_accuracy: 0.9878
# Epoch 4/5
# 422/422 [==============================] - 40s 95ms/step - loss: 0.0707 - accuracy: 0.9771 - val_loss: 0.0419 - val_accuracy: 0.9885
# Epoch 5/5
# ...
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0421 - accuracy: 0.9870
# Test accuracy: 0.9869999885559082
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-2509e339dfa6> in <cell line: 51>()
#      49 # Example usage
# ...

# %%
# !pip install tensorflow keras pillow

# %%
from google.colab import files
import io

# Function to preprocess user-provided images
def preprocess_image(image_bytes):
    img = Image.open(io.BytesIO(image_bytes)).convert('L')  # Convert to grayscale
    img = img.resize((28, 28))  # Resize to 28x28
    img_array = np.array(img)
    img_array = img_array.reshape(1, 28, 28, 1).astype('float32') / 255.0  # Reshape and normalize
    return img_array

# Function to predict on user-provided images
def predict_image(model, image_bytes):
    preprocessed_image = preprocess_image(image_bytes)
    prediction = model.predict(preprocessed_image)
    predicted_class = np.argmax(prediction)
    return predicted_class

if __name__ == "__main__":
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
        predicted_digit = predict_image(model, uploaded[fn])
        print("Predicted digit:", predicted_digit)
# Out:
#      <input type="file" id="files-e0567fc5-5dc1-4e02-a5d0-58e4a14072f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0567fc5-5dc1-4e02-a5d0-58e4a14072f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
